# %% [markdown]
# Bernoulli Trial & Binomial Distributions
#
# 1. https://towardsdatascience.com/demystifying-the-binomial-distribution-580475b2bb2a

# %%
import requests
from IPython.core.display import Image, display

image_url = 'binomial.png'
display(Image(filename=image_url))
