# %% [markdown]
# 1. Convert Histogram to relative histogram (percentage). This will be same as probability on y axis.
# 2. Draw a Frequency polygon connecting them
# 3. Increase number of bins and the points come closer (PMF)
# 4. Now drawing a smooth curve will be a density curve (PDF) - use kde plot (Kernel Density Estimation Plot)
# 5. A smoother plot can be parameteric fit plot

# %%
import requests
from IPython.core.display import Image, display

#image_url = "https://raw.githubusercontent.com/datavector-io/datascience/main/01-Data_Visualization_Basics/anatomy.png"
#display(Image(requests.get(image_url).content)) #localfile can be displayed with filename= named param
image_url = 'pmf-pdf.png'
display(Image(filename=image_url))

# %%
image_url = 'pmf-pdf-2.png'
display(Image(filename=image_url))

# %% [markdown]
# # References
#
# 1. https://towardsdatascience.com/probability-mass-and-density-functions-eab86a81d021
# 2. https://towardsdatascience.com/probability-distribution-functions-demystified-a6e882759af3
# 3. https://www.youtube.com/channel/UC6AVa0vSrCpuskzGDDKz_EQ
# 4. https://towardsdatascience.com/statistics-is-the-grammar-of-data-science-part-2-8be5685065b5
# 5. https://towardsdatascience.com/5-probability-distribution-you-should-know-as-a-data-scientist-f8abc9522af0

# %% [markdown]
# ## Analyze and auto fit distribution
#
# Very interesting topic
#
# 1. https://towardsdatascience.com/distribution-analyser-b826b88b7b8d
# 2. https://towardsdatascience.com/finding-the-best-distribution-that-fits-your-data-using-pythons-fitter-library-319a5a0972e9
